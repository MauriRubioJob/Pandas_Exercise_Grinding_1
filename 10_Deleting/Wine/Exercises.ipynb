# %% [markdown]
# # Wine

# %% [markdown]
# ### Introduction:
#
# This exercise is a adaptation from the UCI Wine dataset.
# The only pupose is to practice deleting data with pandas.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data).

# %% [markdown]
# ### Step 3. Assign it to a variable called wine

# %%
pd.read_csv?
# Out:
# Signature:
# pd.read_csv(
#     filepath_or_buffer: 'FilePath | ReadCsvBuffer[bytes] | ReadCsvBuffer[str]',
#     *,
#     sep: 'str | None | lib.NoDefault' = <no_default>,
#     delimiter: 'str | None | lib.NoDefault' = None,
#     header: "int | Sequence[int] | None | Literal['infer']" = 'infer',
#     names: 'Sequence[Hashable] | None | lib.NoDefault' = <no_default>,
#     index_col: 'IndexLabel | Literal[False] | None' = None,
#     usecols=None,
#     dtype: 'DtypeArg | None' = None,
#     engine: 'CSVEngine | None' = None,
#     converters=None,
#     true_values=None,
#     false_values=None,
#     skipinitialspace: 'bool' = False,
#     skiprows=None,
#     skipfooter: 'int' = 0,
#     nrows: 'int | None' = None,
#     na_values=None,
#     keep_default_na: 'bool' = True,
#     na_filter: 'bool' = True,
#     verbose: 'bool' = False,
#     skip_blank_lines: 'bool' = True,
#     parse_dates: 'bool | Sequence[Hashable] | None' = None,
# ...

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data'
data_set=pd.read_csv(url,sep=",")
data_set
# Out:
#      1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29   5.64  1.04  \
# 0    1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28   4.38  1.05
# 1    1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81   5.68  1.03
# 2    1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18   7.80  0.86
# 3    1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82   4.32  1.04
# 4    1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97   6.75  1.05
# ..  ..    ...   ...   ...   ...  ...   ...   ...   ...   ...    ...   ...
# 172  3  13.71  5.65  2.45  20.5   95  1.68  0.61  0.52  1.06   7.70  0.64
# 173  3  13.40  3.91  2.48  23.0  102  1.80  0.75  0.43  1.41   7.30  0.70
# 174  3  13.27  4.28  2.26  20.0  120  1.59  0.69  0.43  1.35  10.20  0.59
# 175  3  13.17  2.59  2.37  20.0  120  1.65  0.68  0.53  1.46   9.30  0.60
# 176  3  14.13  4.10  2.74  24.5   96  2.05  0.76  0.56  1.35   9.20  0.61
#
#      3.92  1065
# 0    3.40  1050
# 1    3.17  1185
# 2    3.45  1480
# ...

# %% [markdown]
# ### Step 4. Delete the first, fourth, seventh, nineth, eleventh, thirteenth and fourteenth columns

# %%
data_set = data_set.iloc[:,[1,2,4,5,6,9,11]]

# %% [markdown]
# ### Step 5. Assign the columns as below:
#
# The attributes are (donated by Riccardo Leardi, riclea '@' anchem.unige.it):
# 1) alcohol
# 2) malic_acid
# 3) alcalinity_of_ash
# 4) magnesium
# 5) flavanoids
# 6) proanthocyanins
# 7) hue

# %%
data_set=data_set.set_axis(['alcohol', 'malic_acid', 'alcalinity_of_ash', 'magnesium', 'flavanoids','proanthocyanins','hue'], axis=1)

# %% [markdown]
# ### Step 6. Set the values of the first 3 rows from alcohol as NaN

# %%
data_set.loc[:2,"alcohol"] = np.nan

# %%
data_set
# Out:
#      alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0        NaN        1.78               11.2        100        2.65
# 1        NaN        2.36               18.6        101        2.80
# 2        NaN        1.95               16.8        113        3.85
# 3      13.24        2.59               21.0        118        2.80
# 4      14.20        1.76               15.2        112        3.27
# ..       ...         ...                ...        ...         ...
# 172    13.71        5.65               20.5         95        1.68
# 173    13.40        3.91               23.0        102        1.80
# 174    13.27        4.28               20.0        120        1.59
# 175    13.17        2.59               20.0        120        1.65
# 176    14.13        4.10               24.5         96        2.05
#
#      proanthocyanins   hue
# 0               1.28  1.05
# 1               2.81  1.03
# 2               2.18  0.86
# 3               1.82  1.04
# ...

# %% [markdown]
# ### Step 7. Now set the value of the rows 3 and 4 of magnesium as NaN

# %%
data_set.loc[2:3,"magnesium"] = np.nan

# %% [markdown]
# ### Step 8. Fill the value of NaN with the number 10 in alcohol and 100 in magnesium

# %%
data_set.alcohol.fillna(10,inplace=True)
data_set.magnesium.fillna(100,inplace=True)
data_set
# Out:
#      alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      10.00        1.78               11.2      100.0        2.65
# 1      10.00        2.36               18.6      101.0        2.80
# 2      10.00        1.95               16.8      100.0        3.85
# 3      13.24        2.59               21.0      100.0        2.80
# 4      14.20        1.76               15.2      112.0        3.27
# ..       ...         ...                ...        ...         ...
# 172    13.71        5.65               20.5       95.0        1.68
# 173    13.40        3.91               23.0      102.0        1.80
# 174    13.27        4.28               20.0      120.0        1.59
# 175    13.17        2.59               20.0      120.0        1.65
# 176    14.13        4.10               24.5       96.0        2.05
#
#      proanthocyanins   hue
# 0               1.28  1.05
# 1               2.81  1.03
# 2               2.18  0.86
# 3               1.82  1.04
# ...

# %% [markdown]
# ### Step 9. Count the number of missing values

# %%
data_set.isnull().sum()
# Out:
# alcohol              0
# malic_acid           0
# alcalinity_of_ash    0
# magnesium            0
# flavanoids           0
# proanthocyanins      0
# hue                  0
# dtype: int64

# %% [markdown]
# ### Step 10.  Create an array of 10 random numbers up until 10

# %%
random = np.random.randint(10, size = 10)
random
# Out:
# array([8, 0, 5, 2, 4, 5, 4, 6, 5, 3])

# %%
random
# Out:
# array([8, 0, 5, 2, 4, 5, 4, 6, 5, 3])

# %% [markdown]
# ### Step 11.  Use random numbers you generated as an index and assign NaN value to each of cell.

# %%
data_set.iloc[random,:] = np.nan
data_set.iloc[random,:]
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 8      NaN         NaN                NaN        NaN         NaN
# 0      NaN         NaN                NaN        NaN         NaN
# 5      NaN         NaN                NaN        NaN         NaN
# 2      NaN         NaN                NaN        NaN         NaN
# 4      NaN         NaN                NaN        NaN         NaN
# 5      NaN         NaN                NaN        NaN         NaN
# 4      NaN         NaN                NaN        NaN         NaN
# 6      NaN         NaN                NaN        NaN         NaN
# 5      NaN         NaN                NaN        NaN         NaN
# 3      NaN         NaN                NaN        NaN         NaN
#
#    proanthocyanins  hue
# 8              NaN  NaN
# 0              NaN  NaN
# 5              NaN  NaN
# 2              NaN  NaN
# 4              NaN  NaN
# 5              NaN  NaN
# 4              NaN  NaN
# 6              NaN  NaN
# ...

# %% [markdown]
# ### Step 12.  How many missing values do we have?

# %%
data_set.isnull().sum()
# Out:
# alcohol              7
# malic_acid           7
# alcalinity_of_ash    7
# magnesium            7
# flavanoids           7
# proanthocyanins      7
# hue                  7
# dtype: int64

# %% [markdown]
# ### Step 13. Delete the rows that contain missing values

# %%
data_set=data_set.dropna()

# %% [markdown]
# ### Step 14. Print only the non-null values in alcohol

# %%
data_set.alcohol.loc[data_set.alcohol.notnull()]
# Out:
# 1      10.00
# 7      14.83
# 9      14.10
# 10     14.12
# 11     13.75
#        ...
# 172    13.71
# 173    13.40
# 174    13.27
# 175    13.17
# 176    14.13
# Name: alcohol, Length: 170, dtype: float64

# %% [markdown]
# ### Step 15.  Reset the index, so it starts with 0 again

# %%
data_set.reset_index(inplace=True)

# %%
data_set
# Out:
#      index  alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0        1    10.00        2.36               18.6      101.0        2.80
# 1        7    14.83        1.64               14.0       97.0        2.80
# 2        9    14.10        2.16               18.0      105.0        2.95
# 3       10    14.12        1.48               16.8       95.0        2.20
# 4       11    13.75        1.73               16.0       89.0        2.60
# ..     ...      ...         ...                ...        ...         ...
# 165    172    13.71        5.65               20.5       95.0        1.68
# 166    173    13.40        3.91               23.0      102.0        1.80
# 167    174    13.27        4.28               20.0      120.0        1.59
# 168    175    13.17        2.59               20.0      120.0        1.65
# 169    176    14.13        4.10               24.5       96.0        2.05
#
#      proanthocyanins   hue
# 0               2.81  1.03
# ...

# %% [markdown]
# ### BONUS: Create your own question and answer it.
